# %%
import sys
#!{sys.executable} -m pip install bs4


#%run '/Users/macbook/Desktop/projects/Github_Repositories/streamlit_portfolio_job_search/app.py'

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
website_name = 'jobware'
job_name = 'Business Analyst'
ort_ = 'Rietberg'
radius = 50
page_number = 0

job_link = job_name.replace(' ', '%20').lower()
ort_link = ort_.capitalize()
#url = f'https://www.jobware.de/jobsuche?jw_jobname={job_link}&jw_jobort=333**%20{ort_}&jw_ort_distance={radius}'

url = 'https://www.ebay-kleinanzeigen.de/s-jobs/rietberg/data-analyst/k0c102l1363r50'

#url = 'https://www.jobware.de/jobsuche?jw_jobname=business%20analyst&jw_jobort=333**%20Rietberg&jw_ort_distance=50'
def get_data(url):
    
    headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:107.0) Gecko/20100101 Firefox/107.0'}
    r = requests.get(url, headers=headers)
    soup = BeautifulSoup(r.text, "html5lib")
    return soup


def parse(soup):
    results = soup.find_all('div', {'class' : 'aditem-main'})
    print(len(results))
    for item in results:
        jobs = {
            'location' : item.find('div', {'class' : 'aditem-main--top--left'}).text,
            'date' : item.find('div', {'class' : 'aditem-main--top--right'}).text,
            'title': item.find('a', {'class' : 'ellipsis'}).text,
            'company': item.find('a', {'class' : 'j-action j-dont-follow-vip'}).text
            
        }
        #print(jobs)
        df = pd.DataFrame(jobs)
        print(df.head())
    return

soup = get_data(url)
parse(soup)
# Out:
# 13
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [73], in <cell line: 39>()
#      36     return
#      38 soup = get_data(url)
# ---> 39 parse(soup)
#
# Input In [73], in parse(soup)
#      26     jobs = {
#      27         'location' : item.find('div', {'class' : 'aditem-main--top--left'}).text,
#      28         'date' : item.find('div', {'class' : 'aditem-main--top--right'}).text,
#    (...)
#      31
#      32     }
#      33     #print(jobs)
# ---> 34     df = pd.DataFrame(jobs)
#      35     print(df.head())
#      36 return
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:636, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     630     mgr = self._init_mgr(
#     631         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     632     )
#     634 elif isinstance(data, dict):
#     635     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637 elif isinstance(data, ma.MaskedArray):
#     638     import numpy.ma.mrecords as mrecords
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py:502, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     494     arrays = [
#     495         x
#     496         if not hasattr(x, "dtype") or not isinstance(x.dtype, ExtensionDtype)
#     497         else x.copy()
#     498         for x in arrays
#     499     ]
#     500     # TODO: can we get rid of the dt64tz special case above?
# --> 502 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py:120, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     117 if verify_integrity:
#     118     # figure out the index, if necessary
#     119     if index is None:
# --> 120         index = _extract_index(arrays)
#     121     else:
#     122         index = ensure_index(index)
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/construction.py:664, in _extract_index(data)
#     661         raise ValueError("Per-column arrays must each be 1-dimensional")
#     663 if not indexes and not raw_lengths:
# --> 664     raise ValueError("If using all scalar values, you must pass an index")
#     666 elif have_series:
#     667     index = union_indexes(indexes)
#
# ValueError: If using all scalar values, you must pass an index

# %%
website_name = 'jobware'
job_name = 'Business Analyst'
ort_ = 'Rietberg'
radius = 50
page_number = 0

job_link = job_name.replace(' ', '%20').lower()
ort_link = ort_.capitalize()
#url = f'https://www.jobware.de/jobsuche?jw_jobname={job_link}&jw_jobort=333**%20{ort_}&jw_ort_distance={radius}'

url = 'https://www.ebay-kleinanzeigen.de/s-jobs/rietberg/data-analyst/k0c102l1363r50'

#url = 'https://www.jobware.de/jobsuche?jw_jobname=business%20analyst&jw_jobort=333**%20Rietberg&jw_ort_distance=50'
def get_data(url):
    
    headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:107.0) Gecko/20100101 Firefox/107.0'}
    r = requests.get(url, headers=headers)
    soup = BeautifulSoup(r.text, "html5lib")
    return soup


def parse(soup):
    results = soup.find_all('div', {'class' : 'aditem-main'})
    print(len(results))
    n=0
    for item in results:
        n+=1
        location = item.find('div', {'class' : 'aditem-main--top--left'}).text,
        date = item.find('div', {'class' : 'aditem-main--top--right'}).text,
        title = item.find('a', {'class' : 'ellipsis'}).text,
        descp = item.find('p', {'class' : 'aditem-main--middle--description'}).text
        
        print(descp)
        print(len(location), location[0])
        print(len(date), date[0])
        print(len(title), title[0])
        print(len(descp), descp[0])
        print(30*'*')
    return

soup = get_data(url)
parse(soup)
# Out:
# 13
# ✅ Business Intelligence Analyst - Data Science / Visualisierung / K
#
# ✅ Lurse...
# 1
#                                      33154 Salzkotten
#                                                 (19 km)
#
# 1
#
#                                         Gestern, 18:28
# 1 Business Intelligence Analyst - Data Science / Visualisierung / K
# 79 ✅
# ******************************
# Data Analyst (m/w/d) Power BI mit Remote-Anteil (ATLAS TITAN Mitte GmbH, Niederlassung...
# 1
#                                      33332 Gütersloh
#                                                 (10 km)
#
# 1
#
#                                         18.11.2022
# 1 Data Analyst (m/w/d) Power BI mit Remote-Anteil
# 89 D
# ******************************
# ✅ Data Analyst für Datenmodellierung und Kundenbetreuung (m/w/d)
#
# ✅ Lurse...
# 1
#                                      33154 Salzkotten
#                                                 (19 km)
#
# 1
#
#                                         15.11.2022
# 1 Data Analyst für Datenmodellierung und Kundenbetreuung (m/w/d) i
# 76 ✅
# ******************************
# CHECK24 sucht: (Junior) Data Analyst (m/w/d) Hotel
# JETZT BEWERBEN...
# 1
#                                      48155 Münster-​Hafen
#                                                 (55 km)
#
# 1
#
#                                         Gestern, 16:44
# 1 (Junior) Data Analyst (m/w/d) Hotel (Münster)
# 68 C
# ******************************
# Data Analyst/Data Consultant (m/w/d)
# Become a dataful mind!
#
# Wir sind taod. Uns alle...
# 1
#                                      50667 Köln Altstadt
#                                                 (140 km)
#
# 1
#
#                                         Gestern, 08:02
# 1 Data Analyst/Data Consultant (m/w/d)
# 87 D
# ******************************
# ✅Junior Business/Data Analyst (m/w/d)
# ✅SKS Unternehmensberatung GmbH & Co....
# 1
#                                      60311 Altstadt
#                                                 (189 km)
#
# 1
#
#                                         Gestern, 14:03
# 1 Junior Business/Data Analyst (m/w/d) in 60311
# 77 ✅
# ******************************
# ✅ Data Analyst für Marketing in der Softwareentwicklung (m/w/d)
#
# ✅ SEIBERT MEDIA...
# 1
#                                      65185 Wiesbaden
#                                                 (193 km)
#
# 1
#
#                                         Gestern, 11:27
# 1 Data Analyst für Marketing in der Softwareentwicklung (m/w/d) in
# 83 ✅
# ******************************
# ADVERGY GmbH sucht: (Junior) Data Analyst (m/w/d) | Wiesbaden
# JETZT BEWERBEN...
# 1
#                                      55246 Mainz-​Kostheim
#                                                 (199 km)
#
# 1
#
#                                         Gestern, 18:26
# 1 (Junior) Data Analyst (m/w/d) | Wiesbaden
# 79 A
# ******************************
# ADVERGY GmbH sucht: (Junior) Data Analyst (m/w/d) | Wiesbaden
# JETZT BEWERBEN...
# 1
#                                      55246 Mainz-​Kostheim
#                                                 (199 km)
#
# 1
#
#                                         Gestern, 18:26
# 1 (Junior) Data Analyst (m/w/d) | Wiesbaden
# 79 A
# ******************************
# ADVERGY GmbH sucht: Data Analyst (m/w/d) | Hamburg
# JETZT BEWERBEN...
# 1
#                                      20095 Hamburg Altstadt
#                                                 (221 km)
#
# 1
#
#                                         Gestern, 18:26
# 1 Data Analyst (m/w/d) | Hamburg
# 68 A
# ******************************
# ✅ Data Analyst (m/w/d),
# ✅ Voltimum GmbH
# ➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖➖
# ◼ Vollständige...
# 1
#                                      69115 Heidelberg
#                                                 (267 km)
#
# 1
#
#                                         Gestern, 16:21
# 1 Data Analyst (m/w/d) (Voltimum)
# 90 ✅
# ******************************
# Hey!
#
# diconium GmbH, ein tolles Unternehmen, sucht gerade eine(n) Data Analyst / Referent -...
# 1
#                                      70173 Stuttgart-​Mitte
#                                                 (340 km)
#
# 1
#
#                                         Gestern, 07:19
# 1 Data Analyst / Referent - Reporting & Performance Manage Stuttgar
# 94 H
# ******************************
# Hey!
#
# diconium GmbH, ein tolles Unternehmen, sucht gerade eine(n) Data Analyst / Referent -...
# 1
#                                      80539 Schwabing-​Freimann
#                                                 (465 km)
#
# 1
#
#                                         Gestern, 07:17
# 1 Data Analyst / Referent - Reporting & Performance Managem München
# 94 H
# ******************************
